# %%
import pandas as pd

# %%
diabetes = pd.read_csv("./diabetes_data_upload.csv")

# %%
diabetes
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
diabetes.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %%
diabetes_gen=diabetes.groupby(['Gender']).count()
diabetes_gen = diabetes_gen.rename(columns={'Age':'count'})
diabetes_gen
# Out:
#         count  Polyuria  Polydipsia  sudden weight loss  weakness  Polyphagia  \
# Gender
# Female    192       192         192                 192       192         192
# Male      328       328         328                 328       328         328
#
#         Genital thrush  visual blurring  Itching  Irritability  \
# Gender
# Female             192              192      192           192
# Male               328              328      328           328
#
#         delayed healing  partial paresis  muscle stiffness  Alopecia  Obesity  \
# Gender
# Female              192              192               192       192      192
# Male                328              328               328       328      328
#
#         class
# Gender
# Female    192
# Male      328

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(diabetes_gen.index, diabetes_gen['count'])
plt.title('Conteo por edad')
plt.show()

# %%
diabetes_class=diabetes.groupby(['class']).count()
diabetes_class = diabetes_class.rename(columns={'Age':'count'})
diabetes_class
# Out:
#           count  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# class
# Negative    200     200       200         200                 200       200
# Positive    320     320       320         320                 320       320
#
#           Polyphagia  Genital thrush  visual blurring  Itching  Irritability  \
# class
# Negative         200             200              200      200           200
# Positive         320             320              320      320           320
#
#           delayed healing  partial paresis  muscle stiffness  Alopecia  \
# class
# Negative              200              200               200       200
# Positive              320              320               320       320
#
#           Obesity
# class
# Negative      200
# Positive      320

# %%
plt.bar(diabetes_class.index, diabetes_class['count'])
plt.title('')
plt.show()

# %%
plt.hist(diabetes['Age'])
plt.show()
